# %%
#@title Run on TensorFlow 2.x
# %tensorflow_version 2.x

# %%
#@title Import relevant modules
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset from my github
url = 'https://raw.githubusercontent.com/ebkeefe5/MachineLearning/master/DataSets/dataSet.csv'
training_df = pd.read_csv(url)
print(training_df.head(5))

# Scale the label.
training_df["median_house_value"] /= 1000.0

# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0     -114.3      34.2  ...            1.5             66900.0
# 1     -114.5      34.4  ...            1.8             80100.0
# 2     -114.6      33.7  ...            1.6             85700.0
# 3     -114.6      33.6  ...            3.2             73400.0
# 4     -114.6      33.6  ...            1.9             65500.0
#
# [5 rows x 9 columns]
#    longitude  latitude  ...  median_income  median_house_value
# 0     -114.3      34.2  ...            1.5                66.9
# 1     -114.5      34.4  ...            1.8                80.1
# 2     -114.6      33.7  ...            1.6                85.7
# 3     -114.6      33.6  ...            3.2                73.4
# 4     -114.6      33.6  ...            1.9                65.5
#
# [5 rows x 9 columns]

# %%
# Get statistics on the dataset.
training_df.describe()
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# count    17000.0   17000.0  ...        17000.0             17000.0
# mean      -119.6      35.6  ...            3.9               207.3
# std          2.0       2.1  ...            1.9               116.0
# min       -124.3      32.5  ...            0.5                15.0
# 25%       -121.8      33.9  ...            2.6               119.4
# 50%       -118.5      34.2  ...            3.5               180.4
# 75%       -118.0      37.7  ...            4.8               265.0
# max       -114.3      42.0  ...           15.0               500.0
#
# [8 rows x 9 columns]

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the create_model and traing_model functions.")
# Out:
# Defined the create_model and traing_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = 10000
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 30
batch_size = 30

# Specify the feature and the label.
my_feature = "total_rooms"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/30
# 567/567 [==============================] - 1s 958us/step - loss: 805904.3125 - root_mean_squared_error: 897.7217
# Epoch 2/30
# 567/567 [==============================] - 1s 907us/step - loss: 27725.5215 - root_mean_squared_error: 166.5098
# Epoch 3/30
# 567/567 [==============================] - 1s 883us/step - loss: 27093.8359 - root_mean_squared_error: 164.6021
# Epoch 4/30
# 567/567 [==============================] - 1s 924us/step - loss: 26305.9805 - root_mean_squared_error: 162.1912
# Epoch 5/30
# 567/567 [==============================] - 1s 907us/step - loss: 25651.5723 - root_mean_squared_error: 160.1611
# Epoch 6/30
# 567/567 [==============================] - 1s 912us/step - loss: 24769.4805 - root_mean_squared_error: 157.3832
# Epoch 7/30
# 567/567 [==============================] - 1s 914us/step - loss: 24311.9062 - root_mean_squared_error: 155.9228
# Epoch 8/30
# 567/567 [==============================] - 1s 942us/step - loss: 23450.4844 - root_mean_squared_error: 153.1355
# Epoch 9/30
# 567/567 [==============================] - 1s 933us/step - loss: 23171.4121 - root_mean_squared_error: 152.2216
# Epoch 10/30
# 567/567 [==============================] - 1s 946us/step - loss: 22468.3730 - root_mean_squared_error: 149.8945
# Epoch 11/30
# 567/567 [==============================] - 1s 930us/step - loss: 21799.2227 - root_mean_squared_error: 147.6456
# Epoch 12/30
# 567/567 [==============================] - 1s 920us/step - loss: 21557.4551 - root_mean_squared_error: 146.8246
# Epoch 13/30
# 567/567 [==============================] - 1s 974us/step - loss: 20819.5645 - root_mean_squared_error: 144.2899
# Epoch 14/30
# 567/567 [==============================] - 1s 917us/step - loss: 20309.2773 - root_mean_squared_error: 142.5106
# Epoch 15/30
# 567/567 [==============================] - 1s 920us/step - loss: 19932.4570 - root_mean_squared_error: 141.1824
# Epoch 16/30
# 567/567 [==============================] - 1s 948us/step - loss: 19466.7715 - root_mean_squared_error: 139.5234
# Epoch 17/30
# 567/567 [==============================] - 1s 919us/step - loss: 18951.3066 - root_mean_squared_error: 137.6637
# Epoch 18/30
# 567/567 [==============================] - 1s 927us/step - loss: 18600.7227 - root_mean_squared_error: 136.3845
# Epoch 19/30
# 567/567 [==============================] - 1s 914us/step - loss: 18181.5273 - root_mean_squared_error: 134.8389
# Epoch 20/30
# 567/567 [==============================] - 1s 940us/step - loss: 17893.9883 - root_mean_squared_error: 133.7684
# Epoch 21/30
# 567/567 [==============================] - 1s 905us/step - loss: 17573.4531 - root_mean_squared_error: 132.5649
# Epoch 22/30
# 567/567 [==============================] - 1s 921us/step - loss: 17126.8262 - root_mean_squared_error: 130.8695
# Epoch 23/30
# 567/567 [==============================] - 1s 932us/step - loss: 16917.1328 - root_mean_squared_error: 130.0659
# Epoch 24/30
# 567/567 [==============================] - 1s 930us/step - loss: 16577.2520 - root_mean_squared_error: 128.7527
# Epoch 25/30
# 567/567 [==============================] - 1s 903us/step - loss: 16293.4453 - root_mean_squared_error: 127.6458
# Epoch 26/30
# 567/567 [==============================] - 1s 943us/step - loss: 16015.6572 - root_mean_squared_error: 126.5530
# Epoch 27/30
# 567/567 [==============================] - 1s 923us/step - loss: 15880.5400 - root_mean_squared_error: 126.0180
# Epoch 28/30
# 567/567 [==============================] - 1s 937us/step - loss: 15677.1807 - root_mean_squared_error: 125.2085
# Epoch 29/30
# 567/567 [==============================] - 1s 925us/step - loss: 15471.1318 - root_mean_squared_error: 124.3830
# Epoch 30/30
# 567/567 [==============================] - 1s 933us/step - loss: 15317.4961 - root_mean_squared_error: 123.7639
#
# The learned weight for your model is 0.0078
# The learned bias for your model is 132.2434

# %%
def predict_house_values(n, feature, label):
  """Predict house values based on a feature."""

  batch = training_df[feature][10000:10000 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature   label          predicted")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.0f %6.0f %15.0f" % (training_df[feature][10000 + i],
                                   training_df[label][10000 + i],
                                   predicted_values[i][0] ))

# %%
predict_house_values(10, my_feature, my_label)
# Out:
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#  1960     53             148
#  3400     92             159
#  3677     69             161
#  2202     62             149
#  2403     80             151
#  5652    295             176
#  3318    500             158
#  2552    342             152
#  1364    118             143
#  3468    128             159

# %%
my_feature = "population"   # Replace the ? with population or possibly
                   # a different column name.

# Experiment with the hyperparameters.
learning_rate = 0.05
epochs = 3
batch_size = 120

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)
plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)

predict_house_values(15, my_feature, my_label)

# %%
# Define a synthetic feature named rooms_per_person
training_df["rooms_per_person"] = training_df["total_rooms"]/training_df["population"] 

# Don't change the next line.
my_feature = "rooms_per_person"

# Assign values to these three hyperparameters.
learning_rate = 0.05
epochs = 24
batch_size = 30

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df,
                                         my_feature, my_label,
                                         epochs, batch_size)

plot_the_loss_curve(epochs, rmse)
predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/24
# 567/567 [==============================] - 1s 942us/step - loss: 41390.1719 - root_mean_squared_error: 203.4457
# Epoch 2/24
# 567/567 [==============================] - 1s 949us/step - loss: 22066.6328 - root_mean_squared_error: 148.5484
# Epoch 3/24
# 567/567 [==============================] - 1s 923us/step - loss: 15646.4912 - root_mean_squared_error: 125.0859
# Epoch 4/24
# 567/567 [==============================] - 1s 988us/step - loss: 14863.6611 - root_mean_squared_error: 121.9166
# Epoch 5/24
# 567/567 [==============================] - 1s 926us/step - loss: 14763.5908 - root_mean_squared_error: 121.5055
# Epoch 6/24
# 567/567 [==============================] - 1s 932us/step - loss: 14588.8242 - root_mean_squared_error: 120.7842
# Epoch 7/24
# 567/567 [==============================] - 1s 936us/step - loss: 14417.2354 - root_mean_squared_error: 120.0718
# Epoch 8/24
# 567/567 [==============================] - 1s 946us/step - loss: 14258.3184 - root_mean_squared_error: 119.4082
# Epoch 9/24
# 567/567 [==============================] - 1s 940us/step - loss: 14113.0947 - root_mean_squared_error: 118.7985
# Epoch 10/24
# 567/567 [==============================] - 1s 937us/step - loss: 14045.8936 - root_mean_squared_error: 118.5154
# Epoch 11/24
# 567/567 [==============================] - 1s 922us/step - loss: 13924.7090 - root_mean_squared_error: 118.0030
# Epoch 12/24
# 567/567 [==============================] - 1s 942us/step - loss: 13843.2217 - root_mean_squared_error: 117.6572
# Epoch 13/24
# 567/567 [==============================] - 1s 956us/step - loss: 13789.7148 - root_mean_squared_error: 117.4296
# Epoch 14/24
# 567/567 [==============================] - 1s 923us/step - loss: 13723.7881 - root_mean_squared_error: 117.1486
# Epoch 15/24
# 567/567 [==============================] - 1s 962us/step - loss: 13679.7949 - root_mean_squared_error: 116.9607
# Epoch 16/24
# 567/567 [==============================] - 1s 924us/step - loss: 13645.0049 - root_mean_squared_error: 116.8118
# Epoch 17/24
# 567/567 [==============================] - 1s 999us/step - loss: 13606.5742 - root_mean_squared_error: 116.6472
# Epoch 18/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13552.5625 - root_mean_squared_error: 116.4155
# Epoch 19/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13497.0508 - root_mean_squared_error: 116.1768
# Epoch 20/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13512.5039 - root_mean_squared_error: 116.2433
# Epoch 21/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13467.0176 - root_mean_squared_error: 116.0475
# Epoch 22/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13468.0488 - root_mean_squared_error: 116.0519
# Epoch 23/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13425.6465 - root_mean_squared_error: 115.8691
# Epoch 24/24
# 567/567 [==============================] - 1s 1ms/step - loss: 13388.1777 - root_mean_squared_error: 115.7073
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     2     53             189
#     2     92             200
#     2     69             195
#     2     62             211
#     1     80             186
#     2    295             225
#     2    500             210
#     2    342             223
#     4    118             288
#     2    128             214
#     2    187             224
#     3     80             234
#     2    112             225
#     2     95             219
#     2     69             210

# %%
# Generate a correlation matrix.
training_df.corr()
# Out:
#                     longitude  latitude  ...  median_house_value  rooms_per_person
# longitude                 1.0      -0.9  ...                -0.0              -0.1
# latitude                 -0.9       1.0  ...                -0.1               0.1
# housing_median_age       -0.1       0.0  ...                 0.1              -0.1
# total_rooms               0.0      -0.0  ...                 0.1               0.1
# total_bedrooms            0.1      -0.1  ...                 0.0               0.0
# population                0.1      -0.1  ...                -0.0              -0.1
# households                0.1      -0.1  ...                 0.1              -0.0
# median_income            -0.0      -0.1  ...                 0.7               0.2
# median_house_value       -0.0      -0.1  ...                 1.0               0.2
# rooms_per_person         -0.1       0.1  ...                 0.2               1.0
#
# [10 rows x 10 columns]
